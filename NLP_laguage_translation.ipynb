# %% [markdown]
# <a href="https://colab.research.google.com/github/ghowtham12/task-8/blob/main/NLP_laguage_translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/English.csv')
df
# Out:
#                                   English words/sentences
# 0                                                     Hi.
# 1                                                    Run!
# 2                                                    Run!
# 3                                                    Who?
# 4                                                    Wow!
# ...                                                   ...
# 175616  Top-down economics never works, said Obama. "T...
# 175617  A carbon footprint is the amount of carbon dio...
# 175618  Death is something that we're often discourage...
# 175619  Since there are usually multiple websites on a...
# 175620  If someone who doesn't know your background sa...
#
# [175621 rows x 1 columns]

# %%
df1 = df.head(500)

# %%
from deep_translator import GoogleTranslator
german =[]
for i in df1['English words/sentences']:
      a = GoogleTranslator(source='auto', target='de').translate(i)
      german.append(''.join(a))

# %%
ge =pd.Series(german)
ger=pd.DataFrame(ge, columns=["german words"])
ger.head(10)
# Out:
#   german words
# 0          Hi.
# 1      Laufen!
# 2      Laufen!
# 3         Wer?
# 4         Wow!
# 5       Feuer!
# 6       Hilfe!
# 7    Springen.
# 8        Halt!
# 9        Halt!

# %%
spanish =[]
for j in df1['English words/sentences']:
  b = GoogleTranslator(source='auto', target='spanish').translate(j)
  spanish.append(''.join(b))

# %%
sp =pd.Series(spanish)
spa=pd.DataFrame(sp, columns=["spanish words"])
spa.head()
# Out:
#   spanish words
# 0         Hola.
# 1      ¡Correr!
# 2      ¡Correr!
# 3       ¿Quién?
# 4        ¡Guau!

# %%
french =[]
for k in df1['English words/sentences']:
  c = GoogleTranslator(source='auto', target='french').translate(k)
  french.append(''.join(c))

# %%
fe =pd.Series(french)
fer=pd.DataFrame(fe, columns=["french words"])
fer.head()
# Out:
#   french words
# 0       Salut.
# 1      Courir!
# 2      Courir!
# 3         Qui?
# 4        Ouah!

# %%
different_lan = pd.concat([df1,ger,spa,fer],axis=1)
different_lan.head()
# Out:
#   English words/sentences german words spanish words french words
# 0                     Hi.          Hi.         Hola.       Salut.
# 1                    Run!      Laufen!      ¡Correr!      Courir!
# 2                    Run!      Laufen!      ¡Correr!      Courir!
# 3                    Who?         Wer?       ¿Quién?         Qui?
# 4                    Wow!         Wow!        ¡Guau!        Ouah!

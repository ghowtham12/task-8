# %% [markdown]
# <a href="https://colab.research.google.com/github/ghowtham12/task-8/blob/main/NLP_spelling_correction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/English.csv')
df
# Out:
#                                   English words/sentences
# 0                                                     Hi.
# 1                                                    Run!
# 2                                                    Run!
# 3                                                    Who?
# 4                                                    Wow!
# ...                                                   ...
# 175616  Top-down economics never works, said Obama. "T...
# 175617  A carbon footprint is the amount of carbon dio...
# 175618  Death is something that we're often discourage...
# 175619  Since there are usually multiple websites on a...
# 175620  If someone who doesn't know your background sa...
#
# [175621 rows x 1 columns]

# %%
df_1 = df.iloc[:80000,:]
df_2 = df.iloc[80000:,:]
df1 =df_1.head(100)

# %%
df2= df_2.reset_index(drop=True)
df2.head()
# Out:
#        English words/sentences
# 0  Where did I put the hammer?
# 1  Where did Tom go yesterday?
# 2  Where did all the bread go?
# 3  Where did you buy all this?
# 4  Where did you buy all this?

# %%
# !pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from textblob import Word

result=[]
for i in df1['English words/sentences']:  
    
    word = Word(i)
    
    a = word.correct()
    
    result.append(''.join(a))

# %%
se =pd.Series(result)
wor=pd.DataFrame(se, columns=["corrected words"])

# %%
from textblob import TextBlob
result=[]
for i in df2['English words/sentences']: 
  sentence = TextBlob(i)
    
  b = sentence.correct()
    
  result.append(''.join(b))

# %%
sc =pd.Series(result)
sent=pd.DataFrame(sc, columns=["corrected sentence"])

# %%
spell_correction = pd.concat([df1,wor,df2,sent],axis=1)
spell_correction.head()
# Out:
#   English words/sentences corrected words      English words/sentences  \
# 0                     Hi.              In  Where did I put the hammer?
# 1                    Run!             Run  Where did Tom go yesterday?
# 2                    Run!             Run  Where did all the bread go?
# 3                    Who?             Who  Where did you buy all this?
# 4                    Wow!             Now  Where did you buy all this?
#
#             corrected sentence
# 0  There did I put the hammer?
# 1  There did Tom go yesterday?
# 2  There did all the bread go?
# 3  There did you buy all this?
# 4  There did you buy all this?
